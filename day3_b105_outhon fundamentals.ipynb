# %%
firstname='saurabh'

lastname='jaiswal'

# %%
message= f" custom message  {place_holder_1} {place_holder_2}.......{place_holder_n}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 message= f" custom message  {place_holder_1} {place_holeder_2}.......{place_holder_n}"
#
# NameError: name 'place_holder_1' is not defined

# %%
fullname= f"{firstname} {lastname}"
print(fullname)
# Out:
# saurabh jaiswal

# %%
print(fullname.title())
# Out:
# Saurabh Jaiswal

# %%
message = f"keep up good work, {fullname.title()}"
print(message)
# Out:
# keep up good work, Saurabh Jaiswal

# %%
print("Fav_prog:\npython\nc\nc++\njavascript\nswift")
# Out:
# Fav_prog:
# python
# c
# c++
# javascript
# swift

# %%
print("Fav_prog:\n\tpython\n\tc\n\tc++\n\tjavascript\n\tswift")
# Out:
# Fav_prog:
# 	python
# 	c
# 	c++
# 	javascript
# 	swift
